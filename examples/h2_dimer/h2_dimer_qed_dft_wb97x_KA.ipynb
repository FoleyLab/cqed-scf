# %% [markdown]
# # 📘 Notebook: H₂ Dimer Potential Energy Scan with CQED-DFT
#
# 🧠 Overview
#
# This example demonstrates how to compute an intermolecular potential energy curve for an $H_2$ dimer using:
#
# Density Functional Theory (DFT)
# Cavity Quantum Electrodynamics (QED)
# Dispersion-corrected functional (wB97X-D)
#
# We scan the separation between two $H_2$ molecules and observe how the energy changes in the presence of a cavity field.

# %%
import numpy as np
import psi4
import matplotlib.pyplot as plt

from cqed_scf.calculator import CQEDCalculator

# %% [markdown]
# ## 🖥️ Psi4 Configuration
#
# We configure memory, threading, and SCF options.

# %%
psi4.set_memory("2 GB")
psi4.set_num_threads(2)

psi4_options = {
    "basis": "aug-cc-pvdz",
    "scf_type": "df",
    "e_convergence": 1e-10,
    "d_convergence": 1e-8,
    "dft_radial_points": 99,
    "dft_spherical_points": 302,
    "dft_pruning_scheme": "none"
}
# Out:
#   Memory set to   1.863 GiB by Python driver.
#   Threads set to 2 by Python driver.

# %% [markdown]
# # 🔦 QED Parameters
#
# We define the cavity coupling with field polarized along z-axis with coupling strength of 0.05 a.u.

# %%
lambda_vector = np.array([0.0, 0.0, 0.05]) * 0
#omega = 0.07349864501573
omega = 12.7 * 0

# %%
print(f"Dispersion Energy: {energy_disp - energy_no_disp}")
print(f"Gradient: {grad_disp - grad_no_disp}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 print(f"Dispersion Energy: {energy_disp - energy_no_disp}")
#       2 print(f"Gradient: {grad_disp - grad_no_disp}")
#
# NameError: name 'energy_disp' is not defined

# %% [markdown]
# ## 📏 Scan Range
#
# We vary the intermolecular separation:

# %%
d_vals = np.linspace(2.0, 10.0, 41)

# %% [markdown]
# ## 🧮 CQED Calculator
#
# We use $\omega$B97X-D, where the QED-SCF uses wB97X and the dispersion is added separately (handled by psi4)

# %%
calc = CQEDCalculator(
    lambda_vector=lambda_vector,
    psi4_options=psi4_options,
    omega=omega,
    density_fitting=True,
    functional="wb97x-d",
    debug=False,
)

# %% [markdown]
# # 🔁 Perform the Scan
#
# For each separation $𝑑$, we build a geometry and compute the energy.

# %%
energies = []
distances = []

for d in d_vals:

    geom = f"""
    0 1
    H  -0.370000000  0.000000000  0.000000000
    H   0.370000000  0.000000000  0.000000000
    H  -0.370000000  0.000000000  {d}
    H   0.370000000  0.000000000  {d}
    symmetry c1
    no_reorient
    nocom
    """

    print(f"Running d = {d:.3f}")

    E = calc.energy(geom)

    energies.append(E)
    distances.append(d)

distances = np.array(distances)
energies = np.array(energies)
# Out:
# Running d = 2.000
#
# Running CQED-SCF energy calculation...
#
# Functional: wb97x
# Starting CQED-SCF calculation...
# Method: RKS
# Functional: wb97x
# Using density fitting through Psi4 JK.
#
# Scratch directory: /tmp/
#    => Libint2 <=
#
#     Primary   basis highest AM E, G, H:  6, 6, 3
#     Auxiliary basis highest AM E, G, H:  7, 7, 4
#     Onebody   basis highest AM E, G, H:  -, -, -
#     Solid Harmonics ordering:            Gaussian
#
# *** tstart() called on CHEM9QDFT72ALT
# *** at Mon Apr  6 16:35:34 2026
#
#    => Loading Basis Set <=
#
#     Name: AUG-CC-PVDZ
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-4 entry H          line    40 file /Users/jfoley19/miniconda3/envs/psi4_new/share/psi4/basis/aug-cc-pvdz.gbs
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
#                           and Daniel G. A. Smith
#                               RKS Reference
#                         2 Threads,   1907 MiB Core
#          ---------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: c1
#     Full point group: C2v
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          H           -0.370000000000     0.000000000000     0.000000000000     1.007825032230
#          H            0.370000000000     0.000000000000     0.000000000000     1.007825032230
#          H           -0.370000000000     0.000000000000     2.000000000000     1.007825032230
#          H            0.370000000000     0.000000000000     2.000000000000     1.007825032230
#
#   Running in c1 symmetry.
#
#   Rotational constants: A =     30.54555  B =      2.09084  C =      1.95689 [cm^-1]
#   Rotational constants: A = 915732.48078  B =  62681.88831  C =  58666.18776 [MHz]
#   Nuclear repulsion =    2.455681002060365
#
#   Charge       = 0
#   Multiplicity = 1
#   Electrons    = 4
#   Nalpha       = 2
#   Nbeta        = 2
#
#   ==> Algorithm <==
#
#   SCF Algorithm Type is DF.
#   DIIS enabled.
#   MOM disabled.
#   Fractional occupation disabled.
#   Guess Type is SAD.
#   Energy threshold   = 1.00e-10
#   Density threshold  = 1.00e-08
#   Integral threshold = 1.00e-12
#
#   ==> Primary Basis <==
#
#   Basis Set: AUG-CC-PVDZ
#     Blend: AUG-CC-PVDZ
#     Number of shells: 20
#     Number of basis functions: 36
#     Number of Cartesian functions: 36
#     Spherical Harmonics?: true
#     Max angular momentum: 1
#
#   ==> DFT Potential <==
#
#    => LibXC <=
#
#     Version 7.0.0
#     S. Lehtola, C. Steigemann, M. J.T. Oliveira, and M. A.L. Marques.,  SoftwareX 7, 1–5 (2018) (10.1016/j.softx.2017.11.002)
#
#    => Composite Functional: WB97X <=
#
#     wB97X Hyb-GGA Exchange-Correlation Functional
#
#     J.-D. Chai and M. Head-Gordon.,  J. Chem. Phys. 128, 084106 (2008) (10.1063/1.2834918)
#
#     Deriv               =              1
#     GGA                 =           TRUE
#     Meta                =          FALSE
#
#     Exchange Hybrid     =           TRUE
#     MP2 Hybrid          =          FALSE
#
#    => Exchange-Correlation Functionals <=
#
#     1.0000   wB97X range-separated functional
#
#    => Exact (HF) Exchange <=
#
#     0.8423            HF,LR [omega = 0.3000]
#     0.1577               HF
#
#    => LibXC Density Thresholds  <==
#
#     XC_HYB_GGA_XC_WB97X:  1.00E-14
#
#    => Molecular Quadrature <=
#
#     Radial Scheme          =       TREUTLER
#     Pruning Scheme         =           NONE
#     Nuclear Scheme         =       TREUTLER
#
#     Blocking Scheme        =         OCTREE
#     BS radius alpha        =              1
#     Pruning alpha          =              1
#     Radial Points          =             99
#     Spherical Points       =            302
#     Total Points           =         116396
#     Total Blocks           =            916
#     Max Points             =            255
#     Max Functions          =             36
#     Weights Tolerance      =       1.00E-15
#
#    => Loading Basis Set <=
#
#     Name: (AUG-CC-PVDZ AUX)
#     Role: JKFIT
#     Keyword: DF_BASIS_SCF
#     atoms 1-4 entry H          line    70 file /Users/jfoley19/miniconda3/envs/psi4_new/share/psi4/basis/aug-cc-pvdz-jkfit.gbs
#
#   ==> Integral Setup <==
#
#   DFHelper Memory: AOs need 0.004 GiB; user supplied 1.273 GiB.
#   Using in-core AOs.
#
#   ==> MemDFJK: Density-Fitted J/K Matrices <==
#
#     J tasked:                   Yes
#     K tasked:                   Yes
#     wK tasked:                  Yes
#     Omega:                3.000E-01
#     OpenMP threads:               2
#     Memory [MiB]:              1304
#     Algorithm:                 Core
#     Schwarz Cutoff:           1E-12
#     Mask sparsity (%):       0.0000
#     Fitting Condition:        1E-10
#
#    => Auxiliary Basis Set <=
#
#   Basis Set: (AUG-CC-PVDZ AUX)
#     Blend: AUG-CC-PVDZ-JKFIT
#     Number of shells: 48
#     Number of basis functions: 128
#     Number of Cartesian functions: 140
#     Spherical Harmonics?: true
#     Max angular momentum: 2
#
#   Cached 100.0% of DFT collocation blocks in 0.123 [GiB].
#
#   Minimum eigenvalue in the overlap matrix is 1.1911231634E-04.
#   Reciprocal condition number of the overlap matrix is 1.7711412795E-05.
#     Using symmetric orthogonalization.
#
#   ==> Pre-Iterations <==
#
#   SCF Guess: Superposition of Atomic Densities via on-the-fly atomic UHF (no occupation information).
#
#    -------------------------
#     Irrep   Nso     Nmo
#    -------------------------
#      A         36      36
#    -------------------------
#     Total      36      36
#    -------------------------
#
#   ==> Iterations <==
#
#                            Total Energy        Delta E     RMS |[F,P]|
#
#    @DF-RKS iter SAD:    -1.87626205631504   -1.87626e+00   0.00000e+00
#    @DF-RKS iter   1:    -2.32103174522176   -4.44770e-01   1.65132e-03 ADIIS/DIIS
#    @DF-RKS iter   2:    -2.32441602446520   -3.38428e-03   3.28877e-04 ADIIS/DIIS
#    @DF-RKS iter   3:    -2.32460968398774   -1.93660e-04   2.86905e-05 DIIS
#    @DF-RKS iter   4:    -2.32461151370019   -1.82971e-06   2.28931e-06 DIIS
#    @DF-RKS iter   5:    -2.32461152252701   -8.82682e-09   2.07155e-07 DIIS
#    @DF-RKS iter   6:    -2.32461152259770   -7.06968e-11   1.75249e-08 DIIS
#    @DF-RKS iter   7:    -2.32461152259828   -5.76872e-13   1.63483e-09 DIIS
#   Energy and wave function converged.
#
#
#   ==> Post-Iterations <==
#
#    Electrons on quadrature grid:
#       Ntotal   =    3.9999999709 ; deviation = -2.907e-08
#
#     Orbital Energies [Eh]
#     ---------------------
#
#     Doubly Occupied:
#
#        1A     -0.578313     2A     -0.491473
#
#     Virtual:
#
#        3A      0.058992     4A      0.080229     5A      0.091340
#        6A      0.099432     7A      0.178229     8A      0.222700
#        9A      0.256666    10A      0.290969    11A      0.344320
#       12A      0.378806    13A      0.410481    14A      0.411299
#       15A      0.467577    16A      0.502838    17A      0.531712
#       18A      0.549180    19A      0.565267    20A      0.686085
#       21A      0.710574    22A      0.887956    23A      1.132010
#       24A      1.188294    25A      1.485923    26A      1.493188
#       27A      1.538107    28A      1.572680    29A      1.935209
#       30A      1.953569    31A      2.066348    32A      2.092198
#       33A      2.116947    34A      2.227719    35A      3.470677
#       36A      3.559275
#
#     Final Occupation by Irrep:
#               A
#     DOCC [     2 ]
#     NA   [     2 ]
#     NB   [     2 ]
#
#   @DF-RKS Final Energy:    -2.32461152259828
#
#    => Energetics <=
#
#     Nuclear Repulsion Energy =              2.4556810020603650
#     One-Electron Energy =                  -7.0423744836737798
#     Two-Electron Energy =                   2.9598730093846299
#     DFT Exchange-Correlation Energy =      -0.6977910503694942
#     Empirical Dispersion Energy =           0.0000000000000000
#     VV10 Nonlocal Energy =                  0.0000000000000000
#     Total Energy =                         -2.3246115225982784
#
# Computation Completed
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
#
# Properties computed using the SCF density matrix
#
#
#  Multipole Moments:
#
#  ------------------------------------------------------------------------------------
#      Multipole            Electronic (a.u.)      Nuclear  (a.u.)        Total (a.u.)
#  ------------------------------------------------------------------------------------
#
#  L = 1.  Multiply by 2.5417464519 to convert [e a0] to [Debye]
#  Dipole X            :          0.0000000            0.0000000            0.0000000
#  Dipole Y            :          0.0000000            0.0000000            0.0000000
#  Dipole Z            :         -7.5589045            7.5589045            0.0000000
#  Magnitude           :                                                    0.0000000
#
#  ------------------------------------------------------------------------------------
#
# *** tstop() called on CHEM9QDFT72ALT at Mon Apr  6 16:35:34 2026
# Module time:
# 	user time   =       0.64 seconds =       0.01 minutes
# 	system time =       0.05 seconds =       0.00 minutes
# 	total time  =          0 seconds =       0.00 minutes
# Total time:
# 	user time   =       0.64 seconds =       0.01 minutes
# 	system time =       0.05 seconds =       0.00 minutes
# 	total time  =          0 seconds =       0.00 minutes
#    => Loading Basis Set <=
#
#     Name: (AUG-CC-PVDZ AUX)
#     Role: JKFIT
#     Keyword: DF_BASIS_SCF
#     atoms 1-4 entry H          line    70 file /Users/jfoley19/miniconda3/envs/psi4_new/share/psi4/basis/aug-cc-pvdz-jkfit.gbs
#
#
#   Warning: JK type 'DF' found in simple constructor, defaulting to DiskDFJK.
#            Please use the build_JK(primary, auxiliary, options, do_wK, memory)
#            constructor as DiskDFJK has non-optimal performance for many workloads.
#
#
# Scratch directory: /tmp/
#    => Libint2 <=
#
#     Primary   basis highest AM E, G, H:  6, 6, 3
#     Auxiliary basis highest AM E, G, H:  7, 7, 4
#     Onebody   basis highest AM E, G, H:  -, -, -
#     Solid Harmonics ordering:            Gaussian
#
# *** tstart() called on CHEM9QDFT72ALT
# *** at Mon Apr  6 16:35:34 2026
#
#    => Loading Basis Set <=
#
#     Name: AUG-CC-PVDZ
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-4 entry H          line    40 file /Users/jfoley19/miniconda3/envs/psi4_new/share/psi4/basis/aug-cc-pvdz.gbs
#
#    => WB97X-D: Empirical Dispersion <=
#
#     Chai and Head-Gordon Dispersion Correction
#     Chai, J.-D.; Head-Gordon, M. (2010), J. Chem. Phys., 132: 6615-6620
#
#         s6 =       1.000000
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
#                           and Daniel G. A. Smith
#                               RKS Reference
#                         2 Threads,   1907 MiB Core
#          ---------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: c1
#     Full point group: C2v
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          H           -0.370000000000     0.000000000000     0.000000000000     1.007825032230
#          H            0.370000000000     0.000000000000     0.000000000000     1.007825032230
#          H           -0.370000000000     0.000000000000     2.000000000000     1.007825032230
#          H            0.370000000000     0.000000000000     2.000000000000     1.007825032230
#
#   Running in c1 symmetry.
#
#   Rotational constants: A =     30.54555  B =      2.09084  C =      1.95689 [cm^-1]
#   Rotational constants: A = 915732.48078  B =  62681.88831  C =  58666.18776 [MHz]
#   Nuclear repulsion =    2.455681002060365
#
#   Charge       = 0
#   Multiplicity = 1
#   Electrons    = 4
#   Nalpha       = 2
#   Nbeta        = 2
#
#   ==> Algorithm <==
#
#   SCF Algorithm Type is DF.
#   DIIS enabled.
#   MOM disabled.
#   Fractional occupation disabled.
#   Guess Type is SAD.
#   Energy threshold   = 1.00e-10
#   Density threshold  = 1.00e-08
#   Integral threshold = 1.00e-12
#
#   ==> Primary Basis <==
#
#   Basis Set: AUG-CC-PVDZ
#     Blend: AUG-CC-PVDZ
#     Number of shells: 20
#     Number of basis functions: 36
#     Number of Cartesian functions: 36
#     Spherical Harmonics?: true
#     Max angular momentum: 1
#
#   ==> DFT Potential <==
#
#    => LibXC <=
#
#     Version 7.0.0
#     S. Lehtola, C. Steigemann, M. J.T. Oliveira, and M. A.L. Marques.,  SoftwareX 7, 1–5 (2018) (10.1016/j.softx.2017.11.002)
#
#    => Composite Functional: WB97X-D <=
#
#     wB97X-D Hyb-GGA Exchange-Correlation Functional
#
#     J.-D. Chai and M. Head-Gordon.,  Phys. Chem. Chem. Phys. 10, 6615-6620 (2008) (10.1039/B810189B)
#
#     Deriv               =              1
#     GGA                 =           TRUE
#     Meta                =          FALSE
#
#     Exchange Hybrid     =           TRUE
#     MP2 Hybrid          =          FALSE
#
#    => Exchange-Correlation Functionals <=
#
#     1.0000   wB97X-D range-separated functional
#
#    => Exact (HF) Exchange <=
#
#     0.7780            HF,LR [omega = 0.2000]
#     0.2220               HF
#
#    => LibXC Density Thresholds  <==
#
#     XC_HYB_GGA_XC_WB97X_D:  1.00E-14
#
#    => Molecular Quadrature <=
#
#     Radial Scheme          =       TREUTLER
#     Pruning Scheme         =           NONE
#     Nuclear Scheme         =       TREUTLER
#
#     Blocking Scheme        =         OCTREE
#     BS radius alpha        =              1
#     Pruning alpha          =              1
#     Radial Points          =             99
#     Spherical Points       =            302
#     Total Points           =         116396
#     Total Blocks           =            916
#     Max Points             =            255
#     Max Functions          =             36
#     Weights Tolerance      =       1.00E-15
#
#    => Loading Basis Set <=
#
#     Name: (AUG-CC-PVDZ AUX)
#     Role: JKFIT
#     Keyword: DF_BASIS_SCF
#     atoms 1-4 entry H          line    70 file /Users/jfoley19/miniconda3/envs/psi4_new/share/psi4/basis/aug-cc-pvdz-jkfit.gbs
#
#   ==> Integral Setup <==
#
#   DFHelper Memory: AOs need 0.004 GiB; user supplied 1.273 GiB.
#   Using in-core AOs.
#
#   ==> MemDFJK: Density-Fitted J/K Matrices <==
#
#     J tasked:                   Yes
#     K tasked:                   Yes
#     wK tasked:                  Yes
#     Omega:                2.000E-01
#     OpenMP threads:               2
#     Memory [MiB]:              1304
#     Algorithm:                 Core
#     Schwarz Cutoff:           1E-12
#     Mask sparsity (%):       0.0000
#     Fitting Condition:        1E-10
#
#    => Auxiliary Basis Set <=
#
#   Basis Set: (AUG-CC-PVDZ AUX)
#     Blend: AUG-CC-PVDZ-JKFIT
#     Number of shells: 48
#     Number of basis functions: 128
#     Number of Cartesian functions: 140
#     Spherical Harmonics?: true
#     Max angular momentum: 2
#
#   Cached 100.0% of DFT collocation blocks in 0.123 [GiB].
#
#   Minimum eigenvalue in the overlap matrix is 1.1911231634E-04.
#   Reciprocal condition number of the overlap matrix is 1.7711412795E-05.
#     Using symmetric orthogonalization.
#
#   ==> Pre-Iterations <==
#
#   SCF Guess: Superposition of Atomic Densities via on-the-fly atomic UHF (no occupation information).
#
#    -------------------------
#     Irrep   Nso     Nmo
#    -------------------------
#      A         36      36
#    -------------------------
#     Total      36      36
#    -------------------------
#
#   ==> Iterations <==
#
#                            Total Energy        Delta E     RMS |[F,P]|
#
#    @DF-RKS iter SAD:    -1.88877829364387   -1.88878e+00   0.00000e+00
#    @DF-RKS iter   1:    -2.32983029543071   -4.41052e-01   1.73913e-03 ADIIS/DIIS
#    @DF-RKS iter   2:    -2.33305125859911   -3.22096e-03   2.70291e-04 ADIIS/DIIS
#    @DF-RKS iter   3:    -2.33318395586141   -1.32697e-04   3.31091e-05 DIIS
#    @DF-RKS iter   4:    -2.33318635900959   -2.40315e-06   2.21878e-06 DIIS
#    @DF-RKS iter   5:    -2.33318636728707   -8.27748e-09   2.28385e-07 DIIS
#    @DF-RKS iter   6:    -2.33318636736931   -8.22387e-11   1.87835e-08 DIIS
#    @DF-RKS iter   7:    -2.33318636736993   -6.19949e-13   8.58273e-10 DIIS
#   Energy and wave function converged.
#
#
#   ==> Post-Iterations <==
#
#    Electrons on quadrature grid:
#       Ntotal   =    3.9999999836 ; deviation = -1.644e-08
#
#     Orbital Energies [Eh]
#     ---------------------
#
#     Doubly Occupied:
#
#        1A     -0.552422     2A     -0.469231
#
#     Virtual:
#
#        3A      0.051785     4A      0.071882     5A      0.083676
#        6A      0.093624     7A      0.169367     8A      0.216214
#        9A      0.245102    10A      0.282608    11A      0.334805
#       12A      0.371511    13A      0.402382    14A      0.404200
#       15A      0.458387    16A      0.493068    17A      0.522965
#       18A      0.532942    19A      0.554351    20A      0.674117
#       21A      0.701714    22A      0.875625    23A      1.116003
#       24A      1.172552    25A      1.461708    26A      1.468638
#       27A      1.512832    28A      1.552448    29A      1.909500
#       30A      1.927542    31A      2.040550    32A      2.064147
#       33A      2.088725    34A      2.200180    35A      3.446215
#       36A      3.534990
#
#     Final Occupation by Irrep:
#               A
#     DOCC [     2 ]
#     NA   [     2 ]
#     NB   [     2 ]
#
#   @DF-RKS Final Energy:    -2.33318636736993
#
#    => Energetics <=
#
#     Nuclear Repulsion Energy =              2.4556810020603650
#     One-Electron Energy =                  -7.0456589134669327
#     Two-Electron Energy =                   3.0518638991695974
#     DFT Exchange-Correlation Energy =      -0.7945385718199263
#     Empirical Dispersion Energy =          -0.0005337833130356
#     VV10 Nonlocal Energy =                  0.0000000000000000
#     Total Energy =                         -2.3331863673699318
#
# Computation Completed
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
#
# Properties computed using the SCF density matrix
#
#
#  Multipole Moments:
#
#  ------------------------------------------------------------------------------------
#      Multipole            Electronic (a.u.)      Nuclear  (a.u.)        Total (a.u.)
#  ------------------------------------------------------------------------------------
#
#  L = 1.  Multiply by 2.5417464519 to convert [e a0] to [Debye]
#  Dipole X            :          0.0000000            0.0000000            0.0000000
#  Dipole Y            :          0.0000000            0.0000000            0.0000000
#  Dipole Z            :         -7.5589045            7.5589045            0.0000000
#  Magnitude           :                                                    0.0000000
#
#  ------------------------------------------------------------------------------------
# Dispersion correction energy: -0.008574844772 Eh
# Total energy (CQED + dispersion): -2.333186367371 Eh
# Running d = 2.200
#
# Running CQED-SCF energy calculation...
#
# Functional: wb97x
# Starting CQED-SCF calculation...
# Method: RKS
# Functional: wb97x
# Using density fitting through Psi4 JK.
#
# *** tstop() called on CHEM9QDFT72ALT at Mon Apr  6 16:35:35 2026
# Module time:
# 	user time   =       0.56 seconds =       0.01 minutes
# 	system time =       0.05 seconds =       0.00 minutes
# 	total time  =          1 seconds =       0.02 minutes
# Total time:
# 	user time   =       1.41 seconds =       0.02 minutes
# 	system time =       0.10 seconds =       0.00 minutes
# 	total time  =          1 seconds =       0.02 minutes
#
# Scratch directory: /tmp/
#    => Libint2 <=
#
#     Primary   basis highest AM E, G, H:  6, 6, 3
#     Auxiliary basis highest AM E, G, H:  7, 7, 4
#     Onebody   basis highest AM E, G, H:  -, -, -
#     Solid Harmonics ordering:            Gaussian
#
# *** tstart() called on CHEM9QDFT72ALT
# *** at Mon Apr  6 16:35:35 2026
#
#    => Loading Basis Set <=
#
#     Name: AUG-CC-PVDZ
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-4 entry H          line    40 file /Users/jfoley19/miniconda3/envs/psi4_new/share/psi4/basis/aug-cc-pvdz.gbs
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
#                           and Daniel G. A. Smith
#                               RKS Reference
#                         2 Threads,   1907 MiB Core
#          ---------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: c1
#     Full point group: C2v
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          H           -0.370000000000     0.000000000000     0.000000000000     1.007825032230
#          H            0.370000000000     0.000000000000     0.000000000000     1.007825032230
#          H           -0.370000000000     0.000000000000     2.200000000000     1.007825032230
#          H            0.370000000000     0.000000000000     2.200000000000     1.007825032230
#
#   Running in c1 symmetry.
#
#   Rotational constants: A =     30.54555  B =      1.72797  C =      1.63545 [cm^-1]
#   Rotational constants: A = 915732.48078  B =  51803.21348  C =  49029.59702 [MHz]
#   Nuclear repulsion =    2.367245915189515
#
#   Charge       = 0
#   Multiplicity = 1
#   Electrons    = 4
#   Nalpha       = 2
#   Nbeta        = 2
#
#   ==> Algorithm <==
#
#   SCF Algorithm Type is DF.
#   DIIS enabled.
#   MOM disabled.
#   Fractional occupation disabled.
#   Guess Type is SAD.
#   Energy threshold   = 1.00e-10
#   Density threshold  = 1.00e-08
#   Integral threshold = 1.00e-12
#
#   ==> Primary Basis <==
#
#   Basis Set: AUG-CC-PVDZ
#     Blend: AUG-CC-PVDZ
#     Number of shells: 20
#     Number of basis functions: 36
#     Number of Cartesian functions: 36
#     Spherical Harmonics?: true
#     Max angular momentum: 1
#
#   ==> DFT Potential <==
#
#    => LibXC <=
#
#     Version 7.0.0
#     S. Lehtola, C. Steigemann, M. J.T. Oliveira, and M. A.L. Marques.,  SoftwareX 7, 1–5 (2018) (10.1016/j.softx.2017.11.002)
#
#    => Composite Functional: WB97X <=
#
#     wB97X Hyb-GGA Exchange-Correlation Functional
#
#     J.-D. Chai and M. Head-Gordon.,  J. Chem. Phys. 128, 084106 (2008) (10.1063/1.2834918)
#
#     Deriv               =              1
#     GGA                 =           TRUE
#     Meta                =          FALSE
#
#     Exchange Hybrid     =           TRUE
#     MP2 Hybrid          =          FALSE
#
#    => Exchange-Correlation Functionals <=
#
#     1.0000   wB97X range-separated functional
#
#    => Exact (HF) Exchange <=
#
#     0.8423            HF,LR [omega = 0.3000]
#     0.1577               HF
#
#    => LibXC Density Thresholds  <==
#
#     XC_HYB_GGA_XC_WB97X:  1.00E-14
#
#    => Molecular Quadrature <=
#
#     Radial Scheme          =       TREUTLER
#     Pruning Scheme         =           NONE
#     Nuclear Scheme         =       TREUTLER
#
#     Blocking Scheme        =         OCTREE
#     BS radius alpha        =              1
#     Pruning alpha          =              1
#     Radial Points          =             99
#     Spherical Points       =            302
#     Total Points           =         116528
#     Total Blocks           =            928
#     Max Points             =            256
#     Max Functions          =             36
#     Weights Tolerance      =       1.00E-15
#
#    => Loading Basis Set <=
#
#     Name: (AUG-CC-PVDZ AUX)
#     Role: JKFIT
#     Keyword: DF_BASIS_SCF
#     atoms 1-4 entry H          line    70 file /Users/jfoley19/miniconda3/envs/psi4_new/share/psi4/basis/aug-cc-pvdz-jkfit.gbs
#
#   ==> Integral Setup <==
#
#   DFHelper Memory: AOs need 0.004 GiB; user supplied 1.273 GiB.
#   Using in-core AOs.
#
#   ==> MemDFJK: Density-Fitted J/K Matrices <==
#
#     J tasked:                   Yes
#     K tasked:                   Yes
#     wK tasked:                  Yes
#     Omega:                3.000E-01
#     OpenMP threads:               2
#     Memory [MiB]:              1304
#     Algorithm:                 Core
#     Schwarz Cutoff:           1E-12
#     Mask sparsity (%):       0.0000
#     Fitting Condition:        1E-10
#
#    => Auxiliary Basis Set <=
#
#   Basis Set: (AUG-CC-PVDZ AUX)
#     Blend: AUG-CC-PVDZ-JKFIT
#     Number of shells: 48
#     Number of basis functions: 128
#     Number of Cartesian functions: 140
#     Spherical Harmonics?: true
#     Max angular momentum: 2
#
#   Cached 100.0% of DFT collocation blocks in 0.123 [GiB].
#
#   Minimum eigenvalue in the overlap matrix is 1.3177984327E-04.
#   Reciprocal condition number of the overlap matrix is 2.0345514822E-05.
#     Using symmetric orthogonalization.
#
#   ==> Pre-Iterations <==
#
#   SCF Guess: Superposition of Atomic Densities via on-the-fly atomic UHF (no occupation information).
#
#    -------------------------
#     Irrep   Nso     Nmo
#    -------------------------
#      A         36      36
#    -------------------------
#     Total      36      36
#    -------------------------
#
#   ==> Iterations <==
#
#                            Total Energy        Delta E     RMS |[F,P]|
#
#    @DF-RKS iter SAD:    -1.84929355049348   -1.84929e+00   0.00000e+00
#    @DF-RKS iter   1:    -2.32615029152825   -4.76857e-01   1.55570e-03 ADIIS/DIIS
#    @DF-RKS iter   2:    -2.32923494172653   -3.08465e-03   3.19465e-04 ADIIS/DIIS
#    @DF-RKS iter   3:    -2.32942086916130   -1.85927e-04   2.58494e-05 DIIS
#    @DF-RKS iter   4:    -2.32942240690784   -1.53775e-06   1.96193e-06 DIIS
#    @DF-RKS iter   5:    -2.32942241329483   -6.38699e-09   1.65459e-07 DIIS
#    @DF-RKS iter   6:    -2.32942241333956   -4.47322e-11   1.83385e-08 DIIS
#    @DF-RKS iter   7:    -2.32942241334018   -6.19504e-13   1.71697e-09 DIIS
#   Energy and wave function converged.
#
#
#   ==> Post-Iterations <==
#
#    Electrons on quadrature grid:
#       Ntotal   =    3.9999999706 ; deviation = -2.940e-08
#
#     Orbital Energies [Eh]
#     ---------------------
#
#     Doubly Occupied:
#
#        1A     -0.566959     2A     -0.504561
#
#     Virtual:
#
#        3A      0.059897     4A      0.081103     5A      0.091096
#        6A      0.098230     7A      0.183454     8A      0.225169
#        9A      0.248100    10A      0.273643    11A      0.333827
#       12A      0.382916    13A      0.407486    14A      0.411445
#       15A      0.459849    16A      0.487807    17A      0.522118
#       18A      0.542728    19A      0.561780    20A      0.659740
#       21A      0.702159    22A      0.887139    23A      1.131692
#       24A      1.185638    25A      1.479667    26A      1.490575
#       27A      1.496092    28A      1.623730    29A      1.933582
#       30A      1.951010    31A      2.093988    32A      2.113350
#       33A      2.129904    34A      2.167126    35A      3.460472
#       36A      3.551752
#
#     Final Occupation by Irrep:
#               A
#     DOCC [     2 ]
#     NA   [     2 ]
#     NB   [     2 ]
#
#   @DF-RKS Final Energy:    -2.32942241334018
#
#    => Energetics <=
#
#     Nuclear Repulsion Energy =              2.3672459151895153
#     One-Electron Energy =                  -6.8751526911401406
#     Two-Electron Energy =                   2.8712786547678970
#     DFT Exchange-Correlation Energy =      -0.6927942921574535
#     Empirical Dispersion Energy =           0.0000000000000000
#     VV10 Nonlocal Energy =                  0.0000000000000000
#     Total Energy =                         -2.3294224133401813
#
# Computation Completed
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
#
# Properties computed using the SCF density matrix
#
#
#  Multipole Moments:
#
#  ------------------------------------------------------------------------------------
#      Multipole            Electronic (a.u.)      Nuclear  (a.u.)        Total (a.u.)
#  ------------------------------------------------------------------------------------
#
#  L = 1.  Multiply by 2.5417464519 to convert [e a0] to [Debye]
#  Dipole X            :          0.0000000            0.0000000            0.0000000
#  Dipole Y            :         -0.0000000            0.0000000           -0.0000000
#  Dipole Z            :         -8.3147950            8.3147950            0.0000000
#  Magnitude           :                                                    0.0000000
#
#  ------------------------------------------------------------------------------------
#
# *** tstop() called on CHEM9QDFT72ALT at Mon Apr  6 16:35:35 2026
# Module time:
# 	user time   =       0.53 seconds =       0.01 minutes
# 	system time =       0.02 seconds =       0.00 minutes
# 	total time  =          0 seconds =       0.00 minutes
# Total time:
# 	user time   =       1.95 seconds =       0.03 minutes
# 	system time =       0.12 seconds =       0.00 minutes
# 	total time  =          1 seconds =       0.02 minutes
#    => Loading Basis Set <=
#
#     Name: (AUG-CC-PVDZ AUX)
#     Role: JKFIT
#     Keyword: DF_BASIS_SCF
#     atoms 1-4 entry H          line    70 file /Users/jfoley19/miniconda3/envs/psi4_new/share/psi4/basis/aug-cc-pvdz-jkfit.gbs
#
#
#   Warning: JK type 'DF' found in simple constructor, defaulting to DiskDFJK.
#            Please use the build_JK(primary, auxiliary, options, do_wK, memory)
#            constructor as DiskDFJK has non-optimal performance for many workloads.
#
#
# Scratch directory: /tmp/
#    => Libint2 <=
#
#     Primary   basis highest AM E, G, H:  6, 6, 3
#     Auxiliary basis highest AM E, G, H:  7, 7, 4
#     Onebody   basis highest AM E, G, H:  -, -, -
#     Solid Harmonics ordering:            Gaussian
#
# *** tstart() called on CHEM9QDFT72ALT
# *** at Mon Apr  6 16:35:35 2026
#
#    => Loading Basis Set <=
#
#     Name: AUG-CC-PVDZ
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-4 entry H          line    40 file /Users/jfoley19/miniconda3/envs/psi4_new/share/psi4/basis/aug-cc-pvdz.gbs
#
#    => WB97X-D: Empirical Dispersion <=
#
#     Chai and Head-Gordon Dispersion Correction
#     Chai, J.-D.; Head-Gordon, M. (2010), J. Chem. Phys., 132: 6615-6620
#
#         s6 =       1.000000
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
#                           and Daniel G. A. Smith
#                               RKS Reference
#                         2 Threads,   1907 MiB Core
#          ---------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: c1
#     Full point group: C2v
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          H           -0.370000000000     0.000000000000     0.000000000000     1.007825032230
#          H            0.370000000000     0.000000000000     0.000000000000     1.007825032230
#          H           -0.370000000000     0.000000000000     2.200000000000     1.007825032230
#          H            0.370000000000     0.000000000000     2.200000000000     1.007825032230
#
#   Running in c1 symmetry.
#
#   Rotational constants: A =     30.54555  B =      1.72797  C =      1.63545 [cm^-1]
#   Rotational constants: A = 915732.48078  B =  51803.21348  C =  49029.59702 [MHz]
#   Nuclear repulsion =    2.367245915189515
#
#   Charge       = 0
#   Multiplicity = 1
#   Electrons    = 4
#   Nalpha       = 2
#   Nbeta        = 2
#
#   ==> Algorithm <==
#
#   SCF Algorithm Type is DF.
#   DIIS enabled.
#   MOM disabled.
#   Fractional occupation disabled.
#   Guess Type is SAD.
#   Energy threshold   = 1.00e-10
#   Density threshold  = 1.00e-08
#   Integral threshold = 1.00e-12
#
#   ==> Primary Basis <==
#
#   Basis Set: AUG-CC-PVDZ
#     Blend: AUG-CC-PVDZ
#     Number of shells: 20
#     Number of basis functions: 36
#     Number of Cartesian functions: 36
#     Spherical Harmonics?: true
#     Max angular momentum: 1
#
#   ==> DFT Potential <==
#
#    => LibXC <=
#
#     Version 7.0.0
#     S. Lehtola, C. Steigemann, M. J.T. Oliveira, and M. A.L. Marques.,  SoftwareX 7, 1–5 (2018) (10.1016/j.softx.2017.11.002)
#
#    => Composite Functional: WB97X-D <=
#
#     wB97X-D Hyb-GGA Exchange-Correlation Functional
#
#     J.-D. Chai and M. Head-Gordon.,  Phys. Chem. Chem. Phys. 10, 6615-6620 (2008) (10.1039/B810189B)
#
#     Deriv               =              1
#     GGA                 =           TRUE
#     Meta                =          FALSE
#
#     Exchange Hybrid     =           TRUE
#     MP2 Hybrid          =          FALSE
#
#    => Exchange-Correlation Functionals <=
#
#     1.0000   wB97X-D range-separated functional
#
#    => Exact (HF) Exchange <=
#
#     0.7780            HF,LR [omega = 0.2000]
#     0.2220               HF
#
#    => LibXC Density Thresholds  <==
#
#     XC_HYB_GGA_XC_WB97X_D:  1.00E-14
#
#    => Molecular Quadrature <=
#
#     Radial Scheme          =       TREUTLER
#     Pruning Scheme         =           NONE
#     Nuclear Scheme         =       TREUTLER
#
#     Blocking Scheme        =         OCTREE
#     BS radius alpha        =              1
#     Pruning alpha          =              1
#     Radial Points          =             99
#     Spherical Points       =            302
#     Total Points           =         116528
#     Total Blocks           =            928
#     Max Points             =            256
#     Max Functions          =             36
#     Weights Tolerance      =       1.00E-15
#
#    => Loading Basis Set <=
#
#     Name: (AUG-CC-PVDZ AUX)
#     Role: JKFIT
#     Keyword: DF_BASIS_SCF
#     atoms 1-4 entry H          line    70 file /Users/jfoley19/miniconda3/envs/psi4_new/share/psi4/basis/aug-cc-pvdz-jkfit.gbs
#
#   ==> Integral Setup <==
#
#   DFHelper Memory: AOs need 0.004 GiB; user supplied 1.273 GiB.
#   Using in-core AOs.
#
#   ==> MemDFJK: Density-Fitted J/K Matrices <==
#
#     J tasked:                   Yes
#     K tasked:                   Yes
#     wK tasked:                  Yes
#     Omega:                2.000E-01
#     OpenMP threads:               2
#     Memory [MiB]:              1304
#     Algorithm:                 Core
#     Schwarz Cutoff:           1E-12
#     Mask sparsity (%):       0.0000
#     Fitting Condition:        1E-10
#
#    => Auxiliary Basis Set <=
#
#   Basis Set: (AUG-CC-PVDZ AUX)
#     Blend: AUG-CC-PVDZ-JKFIT
#     Number of shells: 48
#     Number of basis functions: 128
#     Number of Cartesian functions: 140
#     Spherical Harmonics?: true
#     Max angular momentum: 2
#
#   Cached 100.0% of DFT collocation blocks in 0.123 [GiB].
#
#   Minimum eigenvalue in the overlap matrix is 1.3177984327E-04.
#   Reciprocal condition number of the overlap matrix is 2.0345514822E-05.
#     Using symmetric orthogonalization.
#
#   ==> Pre-Iterations <==
#
#   SCF Guess: Superposition of Atomic Densities via on-the-fly atomic UHF (no occupation information).
#
#    -------------------------
#     Irrep   Nso     Nmo
#    -------------------------
#      A         36      36
#    -------------------------
#     Total      36      36
#    -------------------------
#
#   ==> Iterations <==
#
#                            Total Energy        Delta E     RMS |[F,P]|
#
#    @DF-RKS iter SAD:    -1.86403574559033   -1.86404e+00   0.00000e+00
#    @DF-RKS iter   1:    -2.33533331212264   -4.71298e-01   1.63785e-03 ADIIS/DIIS
#    @DF-RKS iter   2:    -2.33817414768008   -2.84084e-03   2.58877e-04 ADIIS/DIIS
#    @DF-RKS iter   3:    -2.33829683840872   -1.22691e-04   3.00548e-05 DIIS
#    @DF-RKS iter   4:    -2.33829888819074   -2.04978e-06   1.91622e-06 DIIS
#    @DF-RKS iter   5:    -2.33829889413947   -5.94873e-09   1.84138e-07 DIIS
#    @DF-RKS iter   6:    -2.33829889419343   -5.39639e-11   1.66290e-08 DIIS
#    @DF-RKS iter   7:    -2.33829889419392   -4.82281e-13   8.20907e-10 DIIS
#   Energy and wave function converged.
#
#
#   ==> Post-Iterations <==
#
#    Electrons on quadrature grid:
#       Ntotal   =    3.9999999831 ; deviation = -1.685e-08
#
#     Orbital Energies [Eh]
#     ---------------------
#
#     Doubly Occupied:
#
#        1A     -0.541258     2A     -0.482111
#
#     Virtual:
#
#        3A      0.052776     4A      0.072746     5A      0.083339
#        6A      0.092237     7A      0.174849     8A      0.218855
#        9A      0.236371    10A      0.266006    11A      0.324229
#       12A      0.375463    13A      0.398324    14A      0.405095
#       15A      0.451823    16A      0.477879    17A      0.513332
#       18A      0.526931    19A      0.549945    20A      0.648256
#       21A      0.693043    22A      0.874457    23A      1.115531
#       24A      1.169916    25A      1.455220    26A      1.465884
#       27A      1.471655    28A      1.602483    29A      1.907689
#       30A      1.924999    31A      2.065792    32A      2.085111
#       33A      2.103570    34A      2.139488    35A      3.436066
#       36A      3.527398
#
#     Final Occupation by Irrep:
#               A
#     DOCC [     2 ]
#     NA   [     2 ]
#     NB   [     2 ]
#
#   @DF-RKS Final Energy:    -2.33829889419392
#
#    => Energetics <=
#
#     Nuclear Repulsion Energy =              2.3672459151895153
#     One-Electron Energy =                  -6.8783276537880731
#     Two-Electron Energy =                   2.9634445017688194
#     DFT Exchange-Correlation Energy =      -0.7900023607900557
#     Empirical Dispersion Energy =          -0.0006592965741217
#     VV10 Nonlocal Energy =                  0.0000000000000000
#     Total Energy =                         -2.3382988941939158
#
# Computation Completed
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
#
# Properties computed using the SCF density matrix
#
#
#  Multipole Moments:
#
#  ------------------------------------------------------------------------------------
#      Multipole            Electronic (a.u.)      Nuclear  (a.u.)        Total (a.u.)
#  ------------------------------------------------------------------------------------
#
#  L = 1.  Multiply by 2.5417464519 to convert [e a0] to [Debye]
#  Dipole X            :         -0.0000000            0.0000000           -0.0000000
#  Dipole Y            :         -0.0000000            0.0000000           -0.0000000
#  Dipole Z            :         -8.3147950            8.3147950            0.0000000
#  Magnitude           :                                                    0.0000000
#
#  ------------------------------------------------------------------------------------
# Dispersion correction energy: -0.008876480854 Eh
# Total energy (CQED + dispersion): -2.338298894192 Eh
# Running d = 2.400
#
# Running CQED-SCF energy calculation...
#
# Functional: wb97x
# Starting CQED-SCF calculation...
# Method: RKS
# Functional: wb97x
# Using density fitting through Psi4 JK.
#
# *** tstop() called on CHEM9QDFT72ALT at Mon Apr  6 16:35:35 2026
# Module time:
# 	user time   =       0.53 seconds =       0.01 minutes
# 	system time =       0.03 seconds =       0.00 minutes
# 	total time  =          0 seconds =       0.00 minutes
# Total time:
# 	user time   =       2.68 seconds =       0.04 minutes
# 	system time =       0.16 seconds =       0.00 minutes
# 	total time  =          1 seconds =       0.02 minutes
#
# Scratch directory: /tmp/
#    => Libint2 <=
#
#     Primary   basis highest AM E, G, H:  6, 6, 3
#     Auxiliary basis highest AM E, G, H:  7, 7, 4
#     Onebody   basis highest AM E, G, H:  -, -, -
#     Solid Harmonics ordering:            Gaussian
#
# *** tstart() called on CHEM9QDFT72ALT
# *** at Mon Apr  6 16:35:35 2026
#
#    => Loading Basis Set <=
#
#     Name: AUG-CC-PVDZ
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-4 entry H          line    40 file /Users/jfoley19/miniconda3/envs/psi4_new/share/psi4/basis/aug-cc-pvdz.gbs
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
#                           and Daniel G. A. Smith
#                               RKS Reference
#                         2 Threads,   1907 MiB Core
#          ---------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: c1
#     Full point group: C2v
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          H           -0.370000000000     0.000000000000     0.000000000000     1.007825032230
#          H            0.370000000000     0.000000000000     0.000000000000     1.007825032230
#          H           -0.370000000000     0.000000000000     2.400000000000     1.007825032230
#          H            0.370000000000     0.000000000000     2.400000000000     1.007825032230
#
#   Running in c1 symmetry.
#
#   Rotational constants: A =     30.54555  B =      1.45197  C =      1.38609 [cm^-1]
#   Rotational constants: A = 915732.48078  B =  43529.08910  C =  41553.83891 [MHz]
#   Nuclear repulsion =    2.292594076963843
#
#   Charge       = 0
#   Multiplicity = 1
#   Electrons    = 4
#   Nalpha       = 2
#   Nbeta        = 2
#
#   ==> Algorithm <==
#
#   SCF Algorithm Type is DF.
#   DIIS enabled.
#   MOM disabled.
#   Fractional occupation disabled.
#   Guess Type is SAD.
#   Energy threshold   = 1.00e-10
#   Density threshold  = 1.00e-08
#   Integral threshold = 1.00e-12
#
#   ==> Primary Basis <==
#
#   Basis Set: AUG-CC-PVDZ
#     Blend: AUG-CC-PVDZ
#     Number of shells: 20
#     Number of basis functions: 36
#     Number of Cartesian functions: 36
#     Spherical Harmonics?: true
#     Max angular momentum: 1
#
#   ==> DFT Potential <==
#
#    => LibXC <=
#
#     Version 7.0.0
#     S. Lehtola, C. Steigemann, M. J.T. Oliveira, and M. A.L. Marques.,  SoftwareX 7, 1–5 (2018) (10.1016/j.softx.2017.11.002)
#
#    => Composite Functional: WB97X <=
#
#     wB97X Hyb-GGA Exchange-Correlation Functional
#
#     J.-D. Chai and M. Head-Gordon.,  J. Chem. Phys. 128, 084106 (2008) (10.1063/1.2834918)
#
#     Deriv               =              1
#     GGA                 =           TRUE
#     Meta                =          FALSE
#
#     Exchange Hybrid     =           TRUE
#     MP2 Hybrid          =          FALSE
#
#    => Exchange-Correlation Functionals <=
#
#     1.0000   wB97X range-separated functional
#
#    => Exact (HF) Exchange <=
#
#     0.8423            HF,LR [omega = 0.3000]
#     0.1577               HF
#
#    => LibXC Density Thresholds  <==
#
#     XC_HYB_GGA_XC_WB97X:  1.00E-14
#
#    => Molecular Quadrature <=
#
#     Radial Scheme          =       TREUTLER
#     Pruning Scheme         =           NONE
#     Nuclear Scheme         =       TREUTLER
#
#     Blocking Scheme        =         OCTREE
#     BS radius alpha        =              1
#     Pruning alpha          =              1
#     Radial Points          =             99
#     Spherical Points       =            302
#     Total Points           =         116616
#     Total Blocks           =            928
#     Max Points             =            255
#     Max Functions          =             36
#     Weights Tolerance      =       1.00E-15
#
#    => Loading Basis Set <=
#
#     Name: (AUG-CC-PVDZ AUX)
#     Role: JKFIT
#     Keyword: DF_BASIS_SCF
#     atoms 1-4 entry H          line    70 file /Users/jfoley19/miniconda3/envs/psi4_new/share/psi4/basis/aug-cc-pvdz-jkfit.gbs
#
#   ==> Integral Setup <==
#
#   DFHelper Memory: AOs need 0.004 GiB; user supplied 1.274 GiB.
#   Using in-core AOs.
#
#   ==> MemDFJK: Density-Fitted J/K Matrices <==
#
#     J tasked:                   Yes
#     K tasked:                   Yes
#     wK tasked:                  Yes
#     Omega:                3.000E-01
#     OpenMP threads:               2
#     Memory [MiB]:              1304
#     Algorithm:                 Core
#     Schwarz Cutoff:           1E-12
#     Mask sparsity (%):       0.0000
#     Fitting Condition:        1E-10
#
#    => Auxiliary Basis Set <=
#
#   Basis Set: (AUG-CC-PVDZ AUX)
#     Blend: AUG-CC-PVDZ-JKFIT
#     Number of shells: 48
#     Number of basis functions: 128
#     Number of Cartesian functions: 140
#     Spherical Harmonics?: true
#     Max angular momentum: 2
#
#   Cached 100.0% of DFT collocation blocks in 0.123 [GiB].
#
#   Minimum eigenvalue in the overlap matrix is 1.4380606283E-04.
#   Reciprocal condition number of the overlap matrix is 2.3067988917E-05.
#     Using symmetric orthogonalization.
#
#   ==> Pre-Iterations <==
#
#   SCF Guess: Superposition of Atomic Densities via on-the-fly atomic UHF (no occupation information).
#
#    -------------------------
#     Irrep   Nso     Nmo
#    -------------------------
#      A         36      36
#    -------------------------
#     Total      36      36
#    -------------------------
#
#   ==> Iterations <==
#
#                            Total Energy        Delta E     RMS |[F,P]|
#
#    @DF-RKS iter SAD:    -1.82980910508439   -1.82981e+00   0.00000e+00
#    @DF-RKS iter   1:    -2.32875258940338   -4.98943e-01   1.49001e-03 ADIIS/DIIS
#    @DF-RKS iter   2:    -2.33164962475893   -2.89704e-03   3.13886e-04 ADIIS/DIIS
#    @DF-RKS iter   3:    -2.33183185444025   -1.82230e-04   2.38436e-05 DIIS
#    @DF-RKS iter   4:    -2.33183319030646   -1.33587e-06   1.76175e-06 DIIS
#    @DF-RKS iter   5:    -2.33183319540461   -5.09815e-09   1.45889e-07 DIIS
#    @DF-RKS iter   6:    -2.33183319543743   -3.28195e-11   2.05183e-08 DIIS
#    @DF-RKS iter   7:    -2.33183319543818   -7.46958e-13   1.62120e-09 DIIS
#   Energy and wave function converged.
#
#
#   ==> Post-Iterations <==
#
#    Electrons on quadrature grid:
#       Ntotal   =    4.0000000152 ; deviation = 1.516e-08
#
#     Orbital Energies [Eh]
#     ---------------------
#
#     Doubly Occupied:
#
#        1A     -0.558781     2A     -0.514091
#
#     Virtual:
#
#        3A      0.060628     4A      0.081646     5A      0.091038
#        6A      0.097014     7A      0.188151     8A      0.228363
#        9A      0.240947    10A      0.258039    11A      0.324137
#       12A      0.387093    13A      0.404580    14A      0.413497
#       15A      0.450656    16A      0.472755    17A      0.512918
#       18A      0.537261    19A      0.558502    20A      0.639721
#       21A      0.692698    22A      0.874241    23A      1.132764
#       24A      1.182763    25A      1.470692    26A      1.494789
#       27A      1.500719    28A      1.615671    29A      1.929097
#       30A      1.950723    31A      2.091333    32A      2.113183
#       33A      2.144810    34A      2.151774    35A      3.465224
#       36A      3.539692
#
#     Final Occupation by Irrep:
#               A
#     DOCC [     2 ]
#     NA   [     2 ]
#     NB   [     2 ]
#
#   @DF-RKS Final Energy:    -2.33183319543818
#
#    => Energetics <=
#
#     Nuclear Repulsion Energy =              2.2925940769638431
#     One-Electron Energy =                  -6.7302599348455239
#     Two-Electron Energy =                   2.7953433634154345
#     DFT Exchange-Correlation Energy =      -0.6895107009719299
#     Empirical Dispersion Energy =           0.0000000000000000
#     VV10 Nonlocal Energy =                  0.0000000000000000
#     Total Energy =                         -2.3318331954381764
#
# Computation Completed
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
#
# Properties computed using the SCF density matrix
#
#
#  Multipole Moments:
#
#  ------------------------------------------------------------------------------------
#      Multipole            Electronic (a.u.)      Nuclear  (a.u.)        Total (a.u.)
#  ------------------------------------------------------------------------------------
#
#  L = 1.  Multiply by 2.5417464519 to convert [e a0] to [Debye]
#  Dipole X            :          0.0000000            0.0000000            0.0000000
#  Dipole Y            :         -0.0000000            0.0000000           -0.0000000
#  Dipole Z            :         -9.0706854            9.0706854           -0.0000000
#  Magnitude           :                                                    0.0000000
#
#  ------------------------------------------------------------------------------------
#
# ...
#
#    => Molecular Quadrature <=
#
#     Radial Scheme          =       TREUTLER
#     Pruning Scheme         =           NONE
#     Nuclear Scheme         =       TREUTLER
#
#     Blocking Scheme        =         OCTREE
#     BS radius alpha        =              1
#     Pruning alpha          =              1
#     Radial Points          =             99
#     Spherical Points       =            302
#     Total Points           =         117028
#     Total Blocks           =           1032
#     Max Points             =            255
#     Max Functions          =             28
#     Weights Tolerance      =       1.00E-15
#
#    => Loading Basis Set <=
#
#     Name: (AUG-CC-PVDZ AUX)
#     Role: JKFIT
#     Keyword: DF_BASIS_SCF
#     atoms 1-4 entry H          line    70 file /Users/jfoley19/miniconda3/envs/psi4_new/share/psi4/basis/aug-cc-pvdz-jkfit.gbs
#
#   ==> Integral Setup <==
#
#   DFHelper Memory: AOs need 0.003 GiB; user supplied 1.325 GiB.
#   Using in-core AOs.
#
#   ==> MemDFJK: Density-Fitted J/K Matrices <==
#
#     J tasked:                   Yes
#     K tasked:                   Yes
#     wK tasked:                  Yes
#     Omega:                3.000E-01
#     OpenMP threads:               2
#     Memory [MiB]:              1356
#     Algorithm:                 Core
#     Schwarz Cutoff:           1E-12
#     Mask sparsity (%):      29.6296
#     Fitting Condition:        1E-10
#
#    => Auxiliary Basis Set <=
#
#   Basis Set: (AUG-CC-PVDZ AUX)
#     Blend: AUG-CC-PVDZ-JKFIT
#     Number of shells: 48
#     Number of basis functions: 128
#     Number of Cartesian functions: 140
#     Spherical Harmonics?: true
#     Max angular momentum: 2
#
#   Cached 100.0% of DFT collocation blocks in 0.072 [GiB].
#
#   Minimum eigenvalue in the overlap matrix is 2.8447822016E-04.
#   Reciprocal condition number of the overlap matrix is 6.8192641837E-05.
#     Using symmetric orthogonalization.
#
#   ==> Pre-Iterations <==
#
#   SCF Guess: Superposition of Atomic Densities via on-the-fly atomic UHF (no occupation information).
#
#    -------------------------
#     Irrep   Nso     Nmo
#    -------------------------
#      A         36      36
#    -------------------------
#     Total      36      36
#    -------------------------
#
#   ==> Iterations <==
#
#                            Total Energy        Delta E     RMS |[F,P]|
#
#    @DF-RKS iter SAD:    -1.78179993912019   -1.78180e+00   0.00000e+00
#    @DF-RKS iter   1:    -2.33105106689556   -5.49251e-01   1.32196e-03 ADIIS/DIIS
#    @DF-RKS iter   2:    -2.33336031036370   -2.30924e-03   2.80999e-04 ADIIS/DIIS
#    @DF-RKS iter   3:    -2.33350927354258   -1.48963e-04   1.82071e-05 DIIS
#    @DF-RKS iter   4:    -2.33351011715157   -8.43609e-07   1.04443e-06 DIIS
#    @DF-RKS iter   5:    -2.33351011873118   -1.57961e-09   1.20940e-07 DIIS
#    @DF-RKS iter   6:    -2.33351011874864   -1.74647e-11   1.93232e-08 DIIS
#    @DF-RKS iter   7:    -2.33351011874931   -6.65246e-13   4.32678e-11 DIIS
#   Energy and wave function converged.
#
#
#   ==> Post-Iterations <==
#
#    Electrons on quadrature grid:
#       Ntotal   =    3.9999994901 ; deviation = -5.099e-07
#
#     Orbital Energies [Eh]
#     ---------------------
#
#     Doubly Occupied:
#
#        1A     -0.538061     2A     -0.538060
#
#     Virtual:
#
#        3A      0.069509     4A      0.071114     5A      0.077961
#        6A      0.081153     7A      0.209391     8A      0.210869
#        9A      0.268418    10A      0.268418    11A      0.268421
#       12A      0.268421    13A      0.405930    14A      0.408490
#       15A      0.454311    16A      0.454311    17A      0.454313
#       18A      0.454313    19A      0.533290    20A      0.534796
#       21A      0.661008    22A      0.661935    23A      1.137526
#       24A      1.137596    25A      1.475530    26A      1.475530
#       27A      1.475531    28A      1.475531    29A      1.925477
#       30A      1.926757    31A      2.095886    32A      2.095886
#       33A      2.095886    34A      2.095887    35A      3.495365
#       36A      3.495610
#
#     Final Occupation by Irrep:
#               A
#     DOCC [     2 ]
#     NA   [     2 ]
#     NB   [     2 ]
#
#   @DF-RKS Final Energy:    -2.33351011874931
#
#    => Energetics <=
#
#     Nuclear Repulsion Energy =              1.6415909690248707
#     One-Electron Energy =                  -5.4278248644397369
#     Two-Electron Energy =                   2.1380805290644589
#     DFT Exchange-Correlation Energy =      -0.6853567523988999
#     Empirical Dispersion Energy =           0.0000000000000000
#     VV10 Nonlocal Energy =                  0.0000000000000000
#     Total Energy =                         -2.3335101187493068
#
# Computation Completed
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
#
# Properties computed using the SCF density matrix
#
#
#  Multipole Moments:
#
#  ------------------------------------------------------------------------------------
#      Multipole            Electronic (a.u.)      Nuclear  (a.u.)        Total (a.u.)
#  ------------------------------------------------------------------------------------
#
#  L = 1.  Multiply by 2.5417464519 to convert [e a0] to [Debye]
#  Dipole X            :         -0.0000000            0.0000000           -0.0000000
#  Dipole Y            :          0.0000000            0.0000000            0.0000000
#  Dipole Z            :        -37.7945225           37.7945225           -0.0000000
#  Magnitude           :                                                    0.0000000
#
#  ------------------------------------------------------------------------------------
#
# *** tstop() called on CHEM9QDFT72ALT at Mon Apr  6 16:36:04 2026
# Module time:
# 	user time   =       0.49 seconds =       0.01 minutes
# 	system time =       0.02 seconds =       0.00 minutes
# 	total time  =          0 seconds =       0.00 minutes
# Total time:
# 	user time   =      48.15 seconds =       0.80 minutes
# 	system time =       2.13 seconds =       0.04 minutes
# 	total time  =         30 seconds =       0.50 minutes
#    => Loading Basis Set <=
#
#     Name: (AUG-CC-PVDZ AUX)
#     Role: JKFIT
#     Keyword: DF_BASIS_SCF
#     atoms 1-4 entry H          line    70 file /Users/jfoley19/miniconda3/envs/psi4_new/share/psi4/basis/aug-cc-pvdz-jkfit.gbs
#
#
#   Warning: JK type 'DF' found in simple constructor, defaulting to DiskDFJK.
#            Please use the build_JK(primary, auxiliary, options, do_wK, memory)
#            constructor as DiskDFJK has non-optimal performance for many workloads.
#
#
# Scratch directory: /tmp/
#    => Libint2 <=
#
#     Primary   basis highest AM E, G, H:  6, 6, 3
#     Auxiliary basis highest AM E, G, H:  7, 7, 4
#     Onebody   basis highest AM E, G, H:  -, -, -
#     Solid Harmonics ordering:            Gaussian
#
# *** tstart() called on CHEM9QDFT72ALT
# *** at Mon Apr  6 16:36:04 2026
#
#    => Loading Basis Set <=
#
#     Name: AUG-CC-PVDZ
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-4 entry H          line    40 file /Users/jfoley19/miniconda3/envs/psi4_new/share/psi4/basis/aug-cc-pvdz.gbs
#
#    => WB97X-D: Empirical Dispersion <=
#
#     Chai and Head-Gordon Dispersion Correction
#     Chai, J.-D.; Head-Gordon, M. (2010), J. Chem. Phys., 132: 6615-6620
#
#         s6 =       1.000000
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
#                           and Daniel G. A. Smith
#                               RKS Reference
#                         2 Threads,   1907 MiB Core
#          ---------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: c1
#     Full point group: C2v
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          H           -0.370000000000     0.000000000000     0.000000000000     1.007825032230
#          H            0.370000000000     0.000000000000     0.000000000000     1.007825032230
#          H           -0.370000000000     0.000000000000    10.000000000000     1.007825032230
#          H            0.370000000000     0.000000000000    10.000000000000     1.007825032230
#
#   Running in c1 symmetry.
#
#   Rotational constants: A =     30.54555  B =      0.08363  C =      0.08341 [cm^-1]
#   Rotational constants: A = 915732.48078  B =   2507.27553  C =   2500.42936 [MHz]
#   Nuclear repulsion =    1.641590969024871
#
#   Charge       = 0
#   Multiplicity = 1
#   Electrons    = 4
#   Nalpha       = 2
#   Nbeta        = 2
#
#   ==> Algorithm <==
#
#   SCF Algorithm Type is DF.
#   DIIS enabled.
#   MOM disabled.
#   Fractional occupation disabled.
#   Guess Type is SAD.
#   Energy threshold   = 1.00e-10
#   Density threshold  = 1.00e-08
#   Integral threshold = 1.00e-12
#
#   ==> Primary Basis <==
#
#   Basis Set: AUG-CC-PVDZ
#     Blend: AUG-CC-PVDZ
#     Number of shells: 20
#     Number of basis functions: 36
#     Number of Cartesian functions: 36
#     Spherical Harmonics?: true
#     Max angular momentum: 1
#
#   ==> DFT Potential <==
#
#    => LibXC <=
#
#     Version 7.0.0
#     S. Lehtola, C. Steigemann, M. J.T. Oliveira, and M. A.L. Marques.,  SoftwareX 7, 1–5 (2018) (10.1016/j.softx.2017.11.002)
#
#    => Composite Functional: WB97X-D <=
#
#     wB97X-D Hyb-GGA Exchange-Correlation Functional
#
#     J.-D. Chai and M. Head-Gordon.,  Phys. Chem. Chem. Phys. 10, 6615-6620 (2008) (10.1039/B810189B)
#
#     Deriv               =              1
#     GGA                 =           TRUE
#     Meta                =          FALSE
#
#     Exchange Hybrid     =           TRUE
#     MP2 Hybrid          =          FALSE
#
#    => Exchange-Correlation Functionals <=
#
#     1.0000   wB97X-D range-separated functional
#
#    => Exact (HF) Exchange <=
#
#     0.7780            HF,LR [omega = 0.2000]
#     0.2220               HF
#
#    => LibXC Density Thresholds  <==
#
#     XC_HYB_GGA_XC_WB97X_D:  1.00E-14
#
#    => Molecular Quadrature <=
#
#     Radial Scheme          =       TREUTLER
#     Pruning Scheme         =           NONE
#     Nuclear Scheme         =       TREUTLER
#
#     Blocking Scheme        =         OCTREE
#     BS radius alpha        =              1
#     Pruning alpha          =              1
#     Radial Points          =             99
#     Spherical Points       =            302
#     Total Points           =         117028
#     Total Blocks           =           1032
#     Max Points             =            255
#     Max Functions          =             28
#     Weights Tolerance      =       1.00E-15
#
#    => Loading Basis Set <=
#
#     Name: (AUG-CC-PVDZ AUX)
#     Role: JKFIT
#     Keyword: DF_BASIS_SCF
#     atoms 1-4 entry H          line    70 file /Users/jfoley19/miniconda3/envs/psi4_new/share/psi4/basis/aug-cc-pvdz-jkfit.gbs
#
#   ==> Integral Setup <==
#
#   DFHelper Memory: AOs need 0.003 GiB; user supplied 1.325 GiB.
#   Using in-core AOs.
#
#   ==> MemDFJK: Density-Fitted J/K Matrices <==
#
#     J tasked:                   Yes
#     K tasked:                   Yes
#     wK tasked:                  Yes
#     Omega:                2.000E-01
#     OpenMP threads:               2
#     Memory [MiB]:              1356
#     Algorithm:                 Core
#     Schwarz Cutoff:           1E-12
#     Mask sparsity (%):      29.6296
#     Fitting Condition:        1E-10
#
#    => Auxiliary Basis Set <=
#
#   Basis Set: (AUG-CC-PVDZ AUX)
#     Blend: AUG-CC-PVDZ-JKFIT
#     Number of shells: 48
#     Number of basis functions: 128
#     Number of Cartesian functions: 140
#     Spherical Harmonics?: true
#     Max angular momentum: 2
#
#   Cached 100.0% of DFT collocation blocks in 0.072 [GiB].
#
#   Minimum eigenvalue in the overlap matrix is 2.8447822016E-04.
#   Reciprocal condition number of the overlap matrix is 6.8192641837E-05.
#     Using symmetric orthogonalization.
#
#   ==> Pre-Iterations <==
#
#   SCF Guess: Superposition of Atomic Densities via on-the-fly atomic UHF (no occupation information).
#
#    -------------------------
#     Irrep   Nso     Nmo
#    -------------------------
#      A         36      36
#    -------------------------
#     Total      36      36
#    -------------------------
#
#   ==> Iterations <==
#
#                            Total Energy        Delta E     RMS |[F,P]|
#
#    @DF-RKS iter SAD:    -1.80227995208421   -1.80228e+00   0.00000e+00
#    @DF-RKS iter   1:    -2.34124047460290   -5.38961e-01   1.39138e-03 ADIIS/DIIS
#    @DF-RKS iter   2:    -2.34313490500200   -1.89443e-03   2.11305e-04 ADIIS/DIIS
#    @DF-RKS iter   3:    -2.34321826086596   -8.33559e-05   2.22399e-05 DIIS
#    @DF-RKS iter   4:    -2.34321956824965   -1.30738e-06   1.04111e-06 DIIS
#    @DF-RKS iter   5:    -2.34321956965840   -1.40875e-09   2.57423e-08 DIIS
#    @DF-RKS iter   6:    -2.34321956965967   -1.27187e-12   1.65605e-09 DIIS
#   Energy and wave function converged.
#
#
#   ==> Post-Iterations <==
#
#    Electrons on quadrature grid:
#       Ntotal   =    3.9999994709 ; deviation = -5.291e-07
#
#     Orbital Energies [Eh]
#     ---------------------
#
#     Doubly Occupied:
#
#        1A     -0.514406     2A     -0.514406
#
#     Virtual:
#
#        3A      0.062616     4A      0.064121     5A      0.069592
#        6A      0.072667     7A      0.198433     8A      0.199916
#        9A      0.259109    10A      0.259109    11A      0.259111
#       12A      0.259111    13A      0.396442    14A      0.399013
#       15A      0.445137    16A      0.445137    17A      0.445139
#       18A      0.445139    19A      0.517236    20A      0.518783
#       21A      0.649058    22A      0.649976    23A      1.120794
#       24A      1.120866    25A      1.450327    26A      1.450327
#       27A      1.450328    28A      1.450328    29A      1.899000
#       30A      1.900291    31A      2.067254    32A      2.067254
#       33A      2.067255    34A      2.067255    35A      3.470651
#       36A      3.470895
#
#     Final Occupation by Irrep:
#               A
#     DOCC [     2 ]
#     NA   [     2 ]
#     NB   [     2 ]
#
#   @DF-RKS Final Energy:    -2.34321956965967
#
#    => Energetics <=
#
#     Nuclear Repulsion Energy =              1.6415909690248707
#     One-Electron Energy =                  -5.4305933807831810
#     Two-Electron Energy =                   2.2296818287891282
#     DFT Exchange-Correlation Energy =      -0.7838980710614889
#     Empirical Dispersion Energy =          -0.0000009156289998
#     VV10 Nonlocal Energy =                  0.0000000000000000
#     Total Energy =                         -2.3432195696596705
#
# Computation Completed
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
#
# Properties computed using the SCF density matrix
#
#
#  Multipole Moments:
#
#  ------------------------------------------------------------------------------------
#      Multipole            Electronic (a.u.)      Nuclear  (a.u.)        Total (a.u.)
#  ------------------------------------------------------------------------------------
#
#  L = 1.  Multiply by 2.5417464519 to convert [e a0] to [Debye]
#  Dipole X            :         -0.0000000            0.0000000           -0.0000000
#  Dipole Y            :          0.0000000            0.0000000            0.0000000
#  Dipole Z            :        -37.7945225           37.7945225           -0.0000000
#  Magnitude           :                                                    0.0000000
#
#  ------------------------------------------------------------------------------------
# Dispersion correction energy: -0.009709450910 Eh
# Total energy (CQED + dispersion): -2.343219569660 Eh
#
# *** tstop() called on CHEM9QDFT72ALT at Mon Apr  6 16:36:04 2026
# Module time:
# 	user time   =       0.43 seconds =       0.01 minutes
# 	system time =       0.02 seconds =       0.00 minutes
# 	total time  =          0 seconds =       0.00 minutes
# Total time:
# 	user time   =      48.76 seconds =       0.81 minutes
# 	system time =       2.16 seconds =       0.04 minutes
# 	total time  =         30 seconds =       0.50 minutes

# %% [markdown]
# # 💾 Save Data
# Strong recommendation that you update this block to save as a json file :)

# %%
np.savetxt(
    "h2_dimer_scan_qed_dispersion_corrected.dat",
    np.column_stack([distances, energies]),
    header="d (Angstrom)    Energy (Hartree)", fmt=['%.3f', '%.10f'],
    delimiter='\t'
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 np.savetxt(
#       2     "h2_dimer_scan_qed_dispersion_corrected.dat",
# ----> 3     np.column_stack([distances, energies]),
#       4     header="d (Angstrom)    Energy (Hartree)", fmt=['%.3f', '%.10f'],
#       5     delimiter='\t'
#       6 )
#
# NameError: name 'distances' is not defined

# %% [markdown]
# # 📊 Plot the Potential Energy Curve

# %%
plt.figure(figsize=(6,4))
plt.plot(distances, energies, "o-", label="CQED-DFT (wB97X-D)")
plt.xlabel("Separation d (Å)")
plt.ylabel("Energy (Hartree)")
plt.title("H2 Dimer Potential Energy Curve")
plt.grid()
plt.ylim(-2.34951,-2.349)
plt.legend()
plt.show()
